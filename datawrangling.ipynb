# %% [markdown]
# CARLOS FRANCO ARDILES GONZALEZ
# IMPORTANDO LIBRERIAS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# importando archivos excel, dado al formato del excel hay que omitir algunas filas y columnas

# %%
df = pd.read_excel('sdbcol_092021.xlsx', sheet_name='1_02', skiprows=5, na_values='ND')
pd.set_option('display.float_format', '{:.0f}'.format)
df.head(5)
# Out:
#    Unnamed: 0                      Unnamed: 1  2008-01-31 00:00:00  \
# 0         NaN                      Banco Bice              1349841
# 1         NaN     Banco BTG Pactual Chile (9)                  NaN
# 2         NaN             Banco Consorcio (1)                32840
# 3         NaN              Banco de Chile (2)              8012788
# 4         NaN  Banco de Crédito e Inversiones              4855261
#
#    2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00  \
# 0              1377605              1406738              1423720
# 1                  NaN                  NaN                  NaN
# 2                31324                28855                29255
# 3              7999066              7987141              8189996
# 4              4974724              4888666              5029268
#
#    2008-05-31 00:00:00  2008-06-30 00:00:00  2008-07-31 00:00:00  \
# 0              1462320              1505689              1489164
# ...

# %% [markdown]
# elimando columna 1

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df.sample(n=5)
# Out:
#                                            Unnamed: 1  2008-01-31 00:00:00  \
# 14                            Banco Santander - Chile              6850251
# 21                         JP Morgan Chase Bank, N.A.                 9692
# 31  Conceptualización: Vínculo que remite al docum...                  NaN
# 20                                  HSBC Bank (Chile)               168260
# 4                      Banco de Crédito e Inversiones              4855261
#
#     2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00  \
# 14              6881241              6942543              7013911
# 21                12450                12527                12652
# 31                  NaN                  NaN                  NaN
# 20               170881               171539               171646
# 4               4974724              4888666              5029268
#
#     2008-05-31 00:00:00  2008-06-30 00:00:00  2008-07-31 00:00:00  \
# ...

# %%
df.tail(5)
# Out:
#                                            Unnamed: 1  2008-01-31 00:00:00  \
# 27                                                NaN                  NaN
# 28                                                NaN                  NaN
# 29                                ND : No existe dato                  NaN
# 30                                                NaN                  NaN
# 31  Conceptualización: Vínculo que remite al docum...                  NaN
#
#     2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00  \
# 27                  NaN                  NaN                  NaN
# 28                  NaN                  NaN                  NaN
# 29                  NaN                  NaN                  NaN
# 30                  NaN                  NaN                  NaN
# 31                  NaN                  NaN                  NaN
#
#     2008-05-31 00:00:00  2008-06-30 00:00:00  2008-07-31 00:00:00  \
# ...

# %%
filas= [26,27,28,29,30,31]
df = df.drop(index=filas, errors='ignore')

# %% [markdown]
# renombrar columna 1

# %%
df.rename(columns={'Unnamed: 1': 'Institución Financiera'}, inplace=True)

# %%
df.sample(n=5)
# Out:
#                Institución Financiera  2008-01-31 00:00:00  \
# 5   Banco de la Nación Argentina (18)                 4001
# 4      Banco de Crédito e Inversiones              4855261
# 1         Banco BTG Pactual Chile (9)                  NaN
# 7                Banco do Brasil S.A.                 6292
# 18         Deutsche Bank (Chile) (12)                    0
#
#     2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00  \
# 5                  3993                 3911                 3910
# 4               4974724              4888666              5029268
# 1                   NaN                  NaN                  NaN
# 7                  5547                 6228                 6300
# 18                    0                    0                    0
#
#     2008-05-31 00:00:00  2008-06-30 00:00:00  2008-07-31 00:00:00  \
# 5                  3365                 3541                 3588
# 4               5107352              5221524              5265466
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Columns: 166 entries, Institución Financiera to 2021-09-30 00:00:00
# dtypes: float64(165), object(1)
# memory usage: 33.8+ KB

# %%
df.describe()
# Out:
#        2008-01-31  2008-02-29  2008-03-31  2008-04-30  2008-05-31  2008-06-30  \
# count          22          22          22          22          22          22
# mean      1662096     1677390     1684816     1724057     1749133     1785481
# std       2581884     2598105     2602845     2660329     2686074     2745655
# min             0           0           0           0           0           0
# 25%          7142        6564        9621        9327        9457        8500
# 50%        157216      161283      163025      166045      172745      174750
# 75%       3043228     3088608     3134164     3208309     3333226     3376859
# max       8012788     7999066     7987141     8189996     8261600     8452710
#
#        2008-07-31  2008-08-31  2008-09-30  2008-10-31  ...  2020-12-31  \
# count          22          22          22          22  ...          18
# mean      1806457     1829904     1861722     1927461  ...     5900811
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no tenemos datos duplicados

# %%
df['Institución Financiera'].unique()
# Out:
# array(['Banco Bice', 'Banco BTG Pactual Chile (9)', 'Banco Consorcio (1)',
#        'Banco de Chile (2)', 'Banco de Crédito e Inversiones',
#        'Banco de la Nación Argentina (18)', 'Banco del Estado de Chile',
#        'Banco do Brasil S.A.', 'Banco Falabella', 'Banco Internacional',
#        'Banco Itaú Corpbanca (10)', 'Banco Paris (13)',
#        'Banco Penta (14)', 'Banco Ripley', 'Banco Santander - Chile',
#        'Banco Security', 'Banco Sudamericano (4) (5) (6)',
#        'China Construction Bank, Agencia en Chile (11)',
#        'Deutsche Bank (Chile) (12)', 'DnB NOR Bank ASA (7) (8)',
#        'HSBC Bank (Chile)', 'JP Morgan Chase Bank, N.A.',
#        'Rabobank Chile (15)', 'Scotiabank Chile (3) (17)',
#        'The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)',
#        'Bank of China (16)'], dtype=object)

# %%
df['Institución Financiera'].nunique()
# Out:
# 26

# %%
df['Institución Financiera'].value_counts()
# Out:
# Institución Financiera
# Banco Bice                                        1
# Banco BTG Pactual Chile (9)                       1
# The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)     1
# Scotiabank Chile (3) (17)                         1
# Rabobank Chile (15)                               1
# JP Morgan Chase Bank, N.A.                        1
# HSBC Bank (Chile)                                 1
# DnB NOR Bank ASA (7) (8)                          1
# Deutsche Bank (Chile) (12)                        1
# China Construction Bank, Agencia en Chile (11)    1
# Banco Sudamericano (4) (5) (6)                    1
# Banco Security                                    1
# Banco Santander - Chile                           1
# Banco Ripley                                      1
# Banco Penta (14)                                  1
# Banco Paris (13)                                  1
# Banco Itaú Corpbanca (10)                         1
# Banco Internacional                               1
# ...

# %%
df.isnull().sum()
# Out:
# Institución Financiera    0
# 2008-01-31 00:00:00       4
# 2008-02-29 00:00:00       4
# 2008-03-31 00:00:00       4
# 2008-04-30 00:00:00       4
#                          ..
# 2021-05-31 00:00:00       8
# 2021-06-30 00:00:00       8
# 2021-07-31 00:00:00       8
# 2021-08-31 00:00:00       8
# 2021-09-30 00:00:00       8
# Length: 166, dtype: int64

# %% [markdown]
# cantidad de nan

# %%
df.describe()
# Out:
#        2008-01-31  2008-02-29  2008-03-31  2008-04-30  2008-05-31  2008-06-30  \
# count          22          22          22          22          22          22
# mean      1662096     1677390     1684816     1724057     1749133     1785481
# std       2581884     2598105     2602845     2660329     2686074     2745655
# min             0           0           0           0           0           0
# 25%          7142        6564        9621        9327        9457        8500
# 50%        157216      161283      163025      166045      172745      174750
# 75%       3043228     3088608     3134164     3208309     3333226     3376859
# max       8012788     7999066     7987141     8189996     8261600     8452710
#
#        2008-07-31  2008-08-31  2008-09-30  2008-10-31  ...  2020-12-31  \
# count          22          22          22          22  ...          18
# mean      1806457     1829904     1861722     1927461  ...     5900811
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Columns: 166 entries, Institución Financiera to 2021-09-30 00:00:00
# dtypes: float64(165), object(1)
# memory usage: 33.8+ KB

# %% [markdown]
# modificando nombres de encabezados

# %%
df.set_index('Institución Financiera', inplace=True)
encabeza2 = df.columns.tolist()
#cambiar formato de fecha
formatea2 = [pd.to_datetime(x).strftime("%Y-%m-%d") for x in encabeza2]
df.rename(columns=dict(zip(encabeza2, formatea2)), inplace= True)
df.head(2)
# Out:
#                              2008-01-31  2008-02-29  2008-03-31  2008-04-30  \
# Institución Financiera
# Banco Bice                      1349841     1377605     1406738     1423720
# Banco BTG Pactual Chile (9)         NaN         NaN         NaN         NaN
#
#                              2008-05-31  2008-06-30  2008-07-31  2008-08-31  \
# Institución Financiera
# Banco Bice                      1462320     1505689     1489164     1542498
# Banco BTG Pactual Chile (9)         NaN         NaN         NaN         NaN
#
#                              2008-09-30  2008-10-31  ...  2020-12-31  \
# Institución Financiera                               ...
# Banco Bice                      1574889     1640408  ...     4963765
# Banco BTG Pactual Chile (9)         NaN         NaN  ...     1207032
#
#                              2021-01-31  2021-02-28  2021-03-31  2021-04-30  \
# Institución Financiera
# Banco Bice                      5009275     5019182     5066451     5070651
# ...

# %%
df.reset_index(inplace= True)

# %%
df.sample(n=5)
# Out:
#                            Institución Financiera  2008-01-31  2008-02-29  \
# 4                  Banco de Crédito e Inversiones     4855261     4974724
# 9                             Banco Internacional      185209      186270
# 19                       DnB NOR Bank ASA (7) (8)         NaN         NaN
# 0                                      Banco Bice     1349841     1377605
# 24  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)        9745        9612
#
#     2008-03-31  2008-04-30  2008-05-31  2008-06-30  2008-07-31  2008-08-31  \
# 4      4888666     5029268     5107352     5221524     5265466     5371363
# 9       194001      200983      208921      216114      219478      240142
# 19         NaN         NaN         NaN         NaN         NaN         NaN
# 0      1406738     1423720     1462320     1505689     1489164     1542498
# 24        9388        9489        9558        9618        8661        8560
#
# ...

# %% [markdown]
# voy a reemplazar los NaN por 0 ya que estamos trabajando con dinero

# %%
df.fillna(value=0)
# Out:
#                             Institución Financiera  2008-01-31  2008-02-29  \
# 0                                       Banco Bice     1349841     1377605
# 1                      Banco BTG Pactual Chile (9)           0           0
# 2                              Banco Consorcio (1)       32840       31324
# 3                               Banco de Chile (2)     8012788     7999066
# 4                   Banco de Crédito e Inversiones     4855261     4974724
# 5                Banco de la Nación Argentina (18)        4001        3993
# 6                        Banco del Estado de Chile     3593579     3651145
# 7                             Banco do Brasil S.A.        6292        5547
# 8                                  Banco Falabella        3153        3204
# 9                              Banco Internacional      185209      186270
# 10                       Banco Itaú Corpbanca (10)     3994418     4018508
# ...

# %% [markdown]
# agregando las columnas solicitadas

# %%
df.insert(1,'Tipo','Colocación')
df.insert(2,'Sub Tipo','Comercial')
df.insert(3,'Tipo Moneda','Millones de pesos')

# %%
df.head()
# Out:
#            Institución Financiera        Tipo   Sub Tipo        Tipo Moneda  \
# 0                      Banco Bice  Colocación  Comercial  Millones de pesos
# 1     Banco BTG Pactual Chile (9)  Colocación  Comercial  Millones de pesos
# 2             Banco Consorcio (1)  Colocación  Comercial  Millones de pesos
# 3              Banco de Chile (2)  Colocación  Comercial  Millones de pesos
# 4  Banco de Crédito e Inversiones  Colocación  Comercial  Millones de pesos
#
#    2008-01-31  2008-02-29  2008-03-31  2008-04-30  2008-05-31  2008-06-30  \
# 0     1349841     1377605     1406738     1423720     1462320     1505689
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2       32840       31324       28855       29255       29552       28441
# 3     8012788     7999066     7987141     8189996     8261600     8452710
# 4     4855261     4974724     4888666     5029268     5107352     5221524
#
# ...

# %%
df['Institución Financiera']=df['Institución Financiera'].str.replace(r'\(.*\)', '', regex=True)

# %%
df.sample(n=5)
# Out:
#                        Institución Financiera        Tipo   Sub Tipo  \
# 0                                  Banco Bice  Colocación  Comercial
# 14                    Banco Santander - Chile  Colocación  Comercial
# 20                                 HSBC Bank   Colocación  Comercial
# 8                             Banco Falabella  Colocación  Comercial
# 24  The Bank of Tokyo - Mitsubishi Ufj. Ltd.   Colocación  Comercial
#
#           Tipo Moneda  2008-01-31  2008-02-29  2008-03-31  2008-04-30  \
# 0   Millones de pesos     1349841     1377605     1406738     1423720
# 14  Millones de pesos     6850251     6881241     6942543     7013911
# 20  Millones de pesos      168260      170881      171539      171646
# 8   Millones de pesos        3153        3204       11162       18502
# 24  Millones de pesos        9745        9612        9388        9489
#
#     2008-05-31  2008-06-30  ...  2020-12-31  2021-01-31  2021-02-28  \
# ...

# %%
pf = pd.read_excel('sdbcol_092021.xlsx', sheet_name='1_03', skiprows=5, na_values='ND')
pf.drop(columns='Unnamed: 0', inplace=True)

# %%
pf.head()
# Out:
#                        Unnamed: 1  2008-01-31 00:00:00  2008-02-29 00:00:00  \
# 0                      Banco Bice                42485                43752
# 1     Banco BTG Pactual Chile (9)                  NaN                  NaN
# 2             Banco Consorcio (1)                   77                   75
# 3              Banco de Chile (2)              1705989              1711358
# 4  Banco de Crédito e Inversiones               892621               899620
#
#    2008-03-31 00:00:00  2008-04-30 00:00:00  2008-05-31 00:00:00  \
# 0                44301                45176                44412
# 1                  NaN                  NaN                  NaN
# 2                   73                   70                   73
# 3              1722973              1737899              1732349
# 4               908313               926164               926510
#
#    2008-06-30 00:00:00  2008-07-31 00:00:00  2008-08-31 00:00:00  \
# ...

# %%
pf.tail(9)
# Out:
#                                            Unnamed: 1  2008-01-31 00:00:00  \
# 23                          Scotiabank Chile (3) (17)               701849
# 24      The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)                    0
# 25                                 Bank of China (16)                  NaN
# 26                                              Total              7916376
# 27                                                NaN                  NaN
# 28                                                NaN                  NaN
# 29                                ND : No existe dato                  NaN
# 30                                                NaN                  NaN
# 31  Conceptualización: Vínculo que remite al docum...                  NaN
#
#     2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00  \
# 23               709902               724501               735291
# 24                    0                    0                    0
# ...

# %%
filas1= [26,27,28,29,30,31]
pf = pf.drop(index=filas1, errors='ignore')

# %%
pf.rename(columns={'Unnamed: 1': 'Institución Financiera'}, inplace=True)
pf.head(1)
# Out:
#   Institución Financiera  2008-01-31 00:00:00  2008-02-29 00:00:00  \
# 0             Banco Bice                42485                43752
#
#    2008-03-31 00:00:00  2008-04-30 00:00:00  2008-05-31 00:00:00  \
# 0                44301                45176                44412
#
#    2008-06-30 00:00:00  2008-07-31 00:00:00  2008-08-31 00:00:00  \
# 0                44596                45012                45196
#
#    2008-09-30 00:00:00  ...  2020-12-31 00:00:00  2021-01-31 00:00:00  \
# 0                45344  ...               157768               161133
#
#    2021-02-28 00:00:00  2021-03-31 00:00:00  2021-04-30 00:00:00  \
# 0               162503               162761               167319
#
#    2021-05-31 00:00:00  2021-06-30 00:00:00  2021-07-31 00:00:00  \
# 0               168311               168288               167635
#
#    2021-08-31 00:00:00  2021-09-30 00:00:00
# 0               173656               173287
#
# [1 rows x 166 columns]

# %%
pf.set_index('Institución Financiera', inplace=True)
encabeza21 = pf.columns.tolist()
#cambiar formato de fecha
formatea21 = [pd.to_datetime(x).strftime("%Y-%m-%d") for x in encabeza21]
pf.rename(columns=dict(zip(encabeza21, formatea21)), inplace= True)
pf.head(2)
# Out:
#                              2008-01-31  2008-02-29  2008-03-31  2008-04-30  \
# Institución Financiera
# Banco Bice                        42485       43752       44301       45176
# Banco BTG Pactual Chile (9)         NaN         NaN         NaN         NaN
#
#                              2008-05-31  2008-06-30  2008-07-31  2008-08-31  \
# Institución Financiera
# Banco Bice                        44412       44596       45012       45196
# Banco BTG Pactual Chile (9)         NaN         NaN         NaN         NaN
#
#                              2008-09-30  2008-10-31  ...  2020-12-31  \
# Institución Financiera                               ...
# Banco Bice                        45344       45208  ...      157768
# Banco BTG Pactual Chile (9)         NaN         NaN  ...           0
#
#                              2021-01-31  2021-02-28  2021-03-31  2021-04-30  \
# Institución Financiera
# Banco Bice                       161133      162503      162761      167319
# ...

# %%
pf.reset_index(inplace= True)
pf.fillna(value=0)
# Out:
#                             Institución Financiera  2008-01-31  2008-02-29  \
# 0                                       Banco Bice       42485       43752
# 1                      Banco BTG Pactual Chile (9)           0           0
# 2                              Banco Consorcio (1)          77          75
# 3                               Banco de Chile (2)     1705989     1711358
# 4                   Banco de Crédito e Inversiones      892621      899620
# 5                Banco de la Nación Argentina (18)          82          81
# 6                        Banco del Estado de Chile      896801      906327
# 7                             Banco do Brasil S.A.          16          15
# 8                                  Banco Falabella      400028      403638
# 9                              Banco Internacional         285         281
# 10                       Banco Itaú Corpbanca (10)      793744      800343
# ...

# %%
pf.insert(1,'Tipo','Colocación')
pf.insert(2,'Sub Tipo','Consumo')
pf.insert(3,'Tipo Moneda','Millones de pesos')
pf.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15172\3877040566.py in ?()
# ----> 1 pf.insert(1,'Tipo','Colocación')
#       2 pf.insert(2,'Sub Tipo','Consumo')
#       3 pf.insert(3,'Tipo Moneda','Millones de pesos')
#       4 pf.head(3)
#
# c:\Users\franc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4768                 "'self.flags.allows_duplicate_labels' is False."
#    4769             )
#    4770         if not allow_duplicates and column in self.columns:
#    4771             # Should this be a different kind of error??
# -> 4772             raise ValueError(f"cannot insert {column}, already exists")
#    4773         if not isinstance(loc, int):
#    4774             raise TypeError("loc must be int")
#    4775
#
# ...

# %%
pf.isnull().sum()
# Out:
# Institución Financiera    0
# Tipo                      0
# Sub Tipo                  0
# Tipo Moneda               0
# 2008-01-31                4
#                          ..
# 2021-05-31                8
# 2021-06-30                8
# 2021-07-31                8
# 2021-08-31                8
# 2021-09-30                8
# Length: 169, dtype: int64

# %%
pf.fillna(value=0, inplace=True)

# %%
pf.describe()
# Out:
#        2008-01-31  2008-02-29  2008-03-31  2008-04-30  2008-05-31  2008-06-30  \
# count          22          22          22          22          22          22
# mean       359835      362541      366340      370806      370712      372290
# std        591242      595570      602233      609972      610321      613586
# min             0           0           0           0           0           0
# 25%            18          17          17          18          17          16
# 50%         21385       22016       22286       22730       22343       22436
# 75%        626394      633336      643107      651321      655370      658525
# max       2081528     2100220     2126409     2158120     2163087     2176162
#
#        2008-07-31  2008-08-31  2008-09-30  2008-10-31  ...  2020-12-31  \
# count          22          22          22          22  ...          18
# mean       374108      376764      377984      378448  ...      974169
# ...

# %%
pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Columns: 169 entries, Institución Financiera to 2021-09-30
# dtypes: float64(165), object(4)
# memory usage: 34.5+ KB

# %%
pf.max()
# Out:
# Institución Financiera    The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)
# Tipo                                                         Colocación
# Sub Tipo                                                        Consumo
# Tipo Moneda                                           Millones de pesos
# 2008-01-31                                                      2081528
#                                               ...
# 2021-05-31                                                      4181381
# 2021-06-30                                                      4154785
# 2021-07-31                                                      4157158
# 2021-08-31                                                      4151202
# 2021-09-30                                                      4143185
# Length: 169, dtype: object

# %%
pf['Institución Financiera']=pf['Institución Financiera'].str.replace(r'\(.*\)', '', regex=True)
pf.sample(n=5)
# Out:
#            Institución Financiera        Tipo Sub Tipo        Tipo Moneda  \
# 14        Banco Santander - Chile  Colocación  Consumo  Millones de pesos
# 15                 Banco Security  Colocación  Consumo  Millones de pesos
# 1        Banco BTG Pactual Chile   Colocación  Consumo  Millones de pesos
# 25                 Bank of China   Colocación  Consumo  Millones de pesos
# 5   Banco de la Nación Argentina   Colocación  Consumo  Millones de pesos
#
#     2008-01-31  2008-02-29  2008-03-31  2008-04-30  2008-05-31  2008-06-30  \
# 14     2081528     2100220     2126409     2158120     2163087     2176162
# 15       65017       65473       69504       73432       73006       74398
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN         NaN         NaN
# 5           82          81          92          89          92          90
#
# ...

# %%
df['Institución Financiera']=df['Institución Financiera'].astype(str)
pf['Institución Financiera']=pf['Institución Financiera'].astype(str)

# %%
csb= pd.concat([df,pf], ignore_index=True)
csb.to_csv('prueba.csv')
